# %% [markdown]
# PANDAS STUDY

# %%
import pandas as pd

import matplotlib.pyplot  as plt

# %%
p1=pd.Series(["a","b","c"],index=("1","2","3"))

# %%
print(p1)
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
f1=pd.read_csv("titanic.csv")

# %%
print(f1)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# coverting the csv to another file type 


f3=f1.to_csv("f1copy.csv",index="False")
f2=f1.to_excel("f1copy.xlsx",index="False")

# %%
print(f1)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
print(f3)
# Out:
# None

# %%
f1.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.366029
# std     120.810458    0.482295
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
# some attributes 

f1.index
f1.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
f1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
f2=f1['Survived']
f2.mean()
# Out:
# 0.3660287081339713

# %%
f1['Survived'].mean()
# Out:
# 0.3660287081339713

# %%
# sum of all the columns 

f1.sum()
# Out:
# PassengerId    460009
# Survived          153
# dtype: int64

# %%
f1.product()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
#  selecting and viwing the data ....


f1.head(30)
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         0
# 2           894         0
# 3           895         0
# 4           896         1
# 5           897         0
# 6           898         1
# 7           899         0
# 8           900         1
# 9           901         0
# 10          902         0
# 11          903         1
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         0
# 19          911         0
# 20          912         0
# 21          913         0
# 22          914         1
# 23          915         1
# 24          916         1
# 25          917         0
# 26          918         1
# 27          919         0
# 28          920         1
# 29          921         0

# %%
# to view bottom rows.


f1.tail(5)
# Out:
#      PassengerId  Survived
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
# loc function is very important 
# loc function represents the any row by its index 


for i in range(100):
    
 
 print(f1.loc[i])
# Out:
# PassengerId    892
# Survived         0
# Name: 0, dtype: int64
# PassengerId    893
# Survived         0
# Name: 1, dtype: int64
# PassengerId    894
# Survived         0
# Name: 2, dtype: int64
# PassengerId    895
# Survived         0
# Name: 3, dtype: int64
# PassengerId    896
# Survived         1
# Name: 4, dtype: int64
# PassengerId    897
# Survived         0
# Name: 5, dtype: int64
# PassengerId    898
# Survived         1
# Name: 6, dtype: int64
# PassengerId    899
# Survived         0
# Name: 7, dtype: int64
# PassengerId    900
# Survived         1
# Name: 8, dtype: int64
# PassengerId    901
# Survived         0
# Name: 9, dtype: int64
# PassengerId    902
# Survived         0
# Name: 10, dtype: int64
# PassengerId    903
# Survived         1
# Name: 11, dtype: int64
# PassengerId    904
# Survived         1
# Name: 12, dtype: int64
# PassengerId    905
# Survived         0
# Name: 13, dtype: int64
# PassengerId    906
# Survived         1
# Name: 14, dtype: int64
# ...

# %%
# iloc function 

# iloc works by the position like position in the list 


f1.iloc[-1]
# Out:
# PassengerId    1309
# Survived          0
# Name: 417, dtype: int64

# %%
# splitting in the loc and iloc



f1.iloc[:45]
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         0
# 2           894         0
# 3           895         0
# 4           896         1
# 5           897         0
# 6           898         1
# 7           899         0
# 8           900         1
# 9           901         0
# 10          902         0
# 11          903         1
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         0
# 19          911         0
# 20          912         0
# 21          913         0
# 22          914         1
# 23          915         1
# 24          916         1
# 25          917         0
# 26          918         1
# 27          919         0
# 28          920         1
# 29          921         0
# 30          922         0
# 31          923         0
# 32          924         1
# 33          925         0
# ...

# %%
f1[f1["Survived"] ==1]
# Out:
#      PassengerId  Survived
# 4            896         1
# 6            898         1
# 8            900         1
# 11           903         1
# 12           904         1
# ..           ...       ...
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 414         1306         1
#
# [153 rows x 2 columns]

# %%
pd.crosstab(f1["PassengerId"],f1["Survived"])
# Out:
# Survived     0  1
# PassengerId
# 892          1  0
# 893          1  0
# 894          1  0
# 895          1  0
# 896          0  1
# ...         .. ..
# 1305         1  0
# 1306         0  1
# 1307         1  0
# 1308         1  0
# 1309         1  0
#
# [418 rows x 2 columns]

# %%
# groupby    syntax   f1.groupby(["PassengerId"]).mean()
f1.groupby(["PassengerId"]).mean()
# Out:
#              Survived
# PassengerId
# 892               0.0
# 893               0.0
# 894               0.0
# 895               0.0
# 896               1.0
# ...               ...
# 1305              0.0
# 1306              1.0
# 1307              0.0
# 1308              0.0
# 1309              0.0
#
# [418 rows x 1 columns]

# %%
f1.groupby(["PassengerId"]).median()
# Out:
#              Survived
# PassengerId
# 892               0.0
# 893               0.0
# 894               0.0
# 895               0.0
# 896               1.0
# ...               ...
# 1305              0.0
# 1306              1.0
# 1307              0.0
# 1308              0.0
# 1309              0.0
#
# [418 rows x 1 columns]

# %%
f1["PassengerId"].mode()
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
f1.plot()
# Out:
# <Axes: >

# %%
f1["PassengerId"].plot()
# Out:
# <Axes: >

# %%
f1.hist()
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>]], dtype=object)

# %%
# changing the datatype int he columns 

f1["PassengerId"]=f1["PassengerId"].astype(int)

# %%
#f1["PassengerId"]=f1["PassengerId"]..replace(['0.1,34,4,0,1,2345,456,35,45'],'99999999')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 f1["PassengerId"]=f1["PassengerId"].int.replace(['0.1,34,4,0,1,2345,456,35,45'],'99999999')
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'int'

# %%
# MANIPULATING THE DATA

# %%
# FOLLOWING ARE SOME STRING OPERATIONS 
f1.shape
# Out:
# (418, 2)

# %%
e=[0]*418
for i in range(417):
     e[i]=f"p{i}"
     
f1["PassengerId"]=e

# %%
f1
# Out:
#     PassengerId  Survived
# 0            p0         0
# 1            p1         0
# 2            p2         0
# 3            p3         0
# 4            p4         1
# ..          ...       ...
# 413        p413         0
# 414        p414         1
# 415        p415         0
# 416        p416         0
# 417           0         0
#
# [418 rows x 2 columns]

# %%
f1.isna()
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
f1.dropna()
# Out:
#     PassengerId  Survived
# 0            p0         0
# 1            p1         0
# 2            p2         0
# 3            p3         0
# 4            p4         1
# ..          ...       ...
# 413        p413         0
# 414        p414         1
# 415        p415         0
# 416        p416         0
# 417           0         0
#
# [418 rows x 2 columns]

# %%
f1.fillna("yep")
# Out:
#     PassengerId  Survived
# 0            p0         0
# 1            p1         0
# 2            p2         0
# 3            p3         0
# 4            p4         1
# ..          ...       ...
# 413        p413         0
# 414        p414         1
# 415        p415         0
# 416        p416         0
# 417           0         0
#
# [418 rows x 2 columns]

# %%
f1.isnull()
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
some=[0]*418

for i in range(418):
    some[i]=f"x{i}"
    
f1["SOME"]=some

# %%
f1
# Out:
#     PassengerId  Survived  SOME
# 0            p0         0    x0
# 1            p1         0    x1
# 2            p2         0    x2
# 3            p3         0    x3
# 4            p4         1    x4
# ..          ...       ...   ...
# 413        p413         0  x413
# 414        p414         1  x414
# 415        p415         0  x415
# 416        p416         0  x416
# 417           0         0  x417
#
# [418 rows x 3 columns]
